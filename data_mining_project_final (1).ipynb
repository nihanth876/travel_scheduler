# %%
# !pip install ortools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ortools
#   Downloading ortools-9.5.2237-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      |████████████████████████████████| 16.3 MB 6.2 MB/s
# Requirement already satisfied: absl-py>=0.13 in /usr/local/lib/python3.8/dist-packages (from ortools) (1.3.0)
# Collecting protobuf>=4.21.5
#   Downloading protobuf-4.21.11-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
#      |████████████████████████████████| 409 kB 25.2 MB/s
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.8/dist-packages (from ortools) (1.21.6)
# Installing collected packages: protobuf, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.11 which is incompatible.
# tensorflow-metadata 1.11.0 requires protobuf<4,>=3.13, but you have protobuf 4.21.11 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.21.11 which is incompatible.
# Successfully installed ortools-9.5.2237 protobuf-4.21.11

# %%
api_key = ''  #input the api key which has access to distancematrix api,place api,nearbysearch api access

# %%
import requests
place = 'San Diego'
response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address='+str(place)+"&key="+str(api_key))
resp_json_payload = response.json()
#print(resp_json_payload['results'][0]['geometry']['location'])
lats = resp_json_payload['results'][0]['geometry']['location']['lat']
longs = resp_json_payload['results'][0]['geometry']['location']['lng']
print(str(lats)+' '+str(longs))
# Out:
# 32.715738 -117.1610838

# %%
import requests
no_miss = 'San Diego Zoo'
no_miss_final = no_miss+' '+str(place)
response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address='+str(no_miss_final)+"&key="+str(api_key))
resp_json_payload = response.json()
#print(resp_json_payload['results'][0]['geometry']['location'])
lats_nomiss = resp_json_payload['results'][0]['geometry']['location']['lat']
longs_nomiss = resp_json_payload['results'][0]['geometry']['location']['lng']
print(str(lats_nomiss)+' '+str(longs_nomiss))
# Out:
# 32.7360353 -117.1509849

# %% [markdown]
# The schedule for the tour has been developed by making use of the places api to get the details of the nearest tourist attractions and shopping malls in the city that has been specified.
#
# We start from the place provided by user (we assume that the people would arrive at the destination before the schedule of 9AM) and we search for the shopping places nearest to the zoo so that the users can do shopping in the mall(selected shopping mall as there would be a large collection of stores in the mall and the people can also simultaneously have lunch at the restraunts of their choice in the mall instead of taking them seperately to a restraunt for lunch).
#
# In this code cell below we get the details of the shopping malls and popular tourist destinations in the location provided in the form of a pandas dataframe having the columns
#
# 'name' - name of the places
# 'business_status' - whether it is still operational or closed
# 'formatted_address' - the address of the places
# 'rating' - the rating for that particular place indicating if place is good
# 'user_ratings_total' - number of people who rated which can give a rough idea of how many people visited the place, more reviews might mean more people might visit that place.
# 'website' - the website of the place which people can check out
# 'lat' - the latitude of the place
# 'lng' - longitude of the place
# 'type' - type of the place like museum,park etc if we are not able to determine this we say that it is a tourist place

# %%
import pandas as pd
import numpy as np
import json
from bs4 import BeautifulSoup
import json
import requests
from urllib import request
from sklearn.neighbors import BallTree
from io import StringIO


#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=indianapolis+city+point+of+interest&language=en&key="+str(api_key) #url for the google maps api to get popular places in indianapolis
place = str(place).replace(' ','+')
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query="+str(place)+"+city+point+of+interest&language=en&key="+str(api_key)

#this code has the logic to get and parse the json data
text = request.urlopen(url).read()
s = BeautifulSoup(text,'html.parser')
r=json.loads(s.text)
keys = list(r['results'][0].keys())
data_full = r['results']
length = len(data_full)
print(data_full)
print('\n')

check = ['name','business_status','formatted_address','rating','user_ratings_total','website']
check_plus = ['name','business_status','formatted_address','rating','user_ratings_total','website','lat','lng','type'] #the final list of columns for the popular places
df = pd.DataFrame()

#url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=39.7675746,-86.1796262&radius=3000&type=shopping_mall&key="+str(api_key) #url for google maps api to get list of shopping malls near indianapolis zoo
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location="+str(lats_nomiss)+','+str(longs_nomiss)+"&radius=3000&type=shopping_mall&key="+str(api_key)

#this code has the logic to get and parse the json data
text1 = request.urlopen(url).read()
s1 = BeautifulSoup(text1,'html.parser')
malls=json.loads(s1.text)

data_malls = malls['results']
length_malls = len(data_malls)

check_malls = ['name','business_status','formatted_address','rating','user_ratings_total','website']
check_plus_malls = ['name','business_status','formatted_address','rating','user_ratings_total','website','lat','lng','type'] #the final list of columns for the nearby shopping locations

#code to get the details of the nearby tourist destination in indianapolis from the places api
count = 0
for j in range(length):
    data = data_full[j]
    temp = {}
    for i in check:    
        if i in keys:
            if i=='formatted_address':
                print(data[i])
            try:
                temp[i]=data[i]
            except Exception as e:
                temp[i] = ' '
    lat = ''
    long = ''
    try:
        geo = data['geometry']
        location = geo['location']
        lat = location['lat']            #to get the latitude of the location
        lng = location['lng']            #to get longitude of the location
        
        temp['lat'] = str(lat)
        temp['lng'] = str(lng)
    except Exception as e:
        temp['lat'] = ''
        temp['lng'] = ''

    flag=0
    for k in data['types']:
        if k in ['tourist_attraction','point_of_interest','establishment']:
            continue
        else:
            temp['type']=k
            flag=1
    if flag==0:
        temp['type']='tour'
        
    url_dummy = "https://maps.googleapis.com/maps/api/place/details/json?place_id="+str(data["place_id"])+"&key="+str(api_key)  #geting extra details of the location from the places api
    text2 = request.urlopen(url_dummy).read()
    s2 = BeautifulSoup(text2,'html.parser')
    r2=json.loads(s2.text)
    #print(r2['result']['website'])    
    try:
        temp["website"] = r2['result']["website"]
    except Exception as e:
        temp["website"] = ' '
    
    if count==0:
        df = pd.DataFrame(temp,columns = check_plus,index=[0])   #creating the dataframe initially
        count=count+1
    else:
        df1 = pd.DataFrame(temp,columns = check_plus,index=[0])  #appending the dataframe with new rows
        df = pd.concat([df, df1])
print(df)

#code to get the details of the nearby shopping malls near indianapolis zoo from the places api
for j in range(0,length_malls):
    data = data_malls[j]
    temp = {}
    for i in check_malls:    
        if i in keys:
            #print(data[i]) 
            try:
                if data[i]==None:
                    temp[i]=' '
                temp[i]=data[i]
            except Exception as e:
                temp[i]=' '
    lat = ''
    long = ''
    try:
        geo = data['geometry']
        location = geo['location']
        lat = location['lat']           #to get the latitude of the location
        lng = location['lng']           #to get longitude of the location
        
        temp['lat'] = str(lat)
        temp['lng'] = str(lng)
    except Exception as e:
        temp['lat'] = ''
        temp['lng'] = ''
    
    url_dummy = "https://maps.googleapis.com/maps/api/place/details/json?place_id="+str(data["place_id"])+"&key="+str(api_key)  #geting extra details of the location from the places api
    text2 = request.urlopen(url_dummy).read()
    s2 = BeautifulSoup(text2,'html.parser')
    r2=json.loads(s2.text)
    
    try:
        temp["formatted_address"] = r2['result']["formatted_address"]
    except Exception as e:
        temp["formatted_address"] = ' '
    try:
        temp["website"] = r2['result']["website"]
    except Exception as e:
        temp["website"] = ' '
        
    temp['type'] = 'shopping'    
    df1 = pd.DataFrame(temp,columns = check_plus_malls,index=[0])    
    df = pd.concat([df, df1])                 #appending the dataframe with new rows

df.set_index('name', inplace=True)       #setting the index as the name column for easy retrieval of data
df
# Out:
# [{'business_status': 'OPERATIONAL', 'formatted_address': 'San Diego, CA, United States', 'geometry': {'location': {'lat': 32.7341479, 'lng': -117.144553}, 'viewport': {'northeast': {'lat': 32.75186495, 'lng': -117.1208421}, 'southwest': {'lat': 32.70871155, 'lng': -117.1722057}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png', 'icon_background_color': '#4DB546', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet', 'name': 'Balboa Park', 'opening_hours': {'open_now': True}, 'photos': [{'height': 554, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114576663038324379365">A Google User</a>'], 'photo_reference': 'AW30NDzfyMG3d5nVF_xaccfGfqOd0mupOc2pA0tyLpdPi4Mp5Sc0ppy4Yk3do6HZHnbE8wH4yiGFJwirYvBMuexl3INI7Ue-Q1XHeb77if0scp_dHeIaCRC6wz8iRa614Kp1WHmAxYFELfz5163khahwyu1pgTLehh5X2SZ3sQEY-AUKj2bp', 'width': 554}], 'place_id': 'ChIJA8tw-pZU2YARxPYVsDwL8-0', 'plus_code': {'compound_code': 'PVM4+M5 San Diego, California', 'global_code': '8544PVM4+M5'}, 'rating': 4.8, 'reference': 'ChIJA8tw-pZU2YARxPYVsDwL8-0', 'types': ['park', 'tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'user_ratings_total': 65606}, {'business_status': 'OPERATIONAL', 'formatted_address': '4002 Wallace St, San Diego, CA 92110, United States', 'geometry': {'location': {'lat': 32.7549063, 'lng': -117.1976407}, 'viewport': {'northeast': {'lat': 32.757066, 'lng': -117.19259065}, 'southwest': {'lat': 32.75141879999999, 'lng': -117.20179125}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/park-71.png', 'icon_background_color': '#4DB546', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/tree_pinlet', 'name': 'Old Town San Diego State Historic Park', 'opening_hours': {'open_now': False}, 'photos': [{'height': 3024, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111225993029865739105">Joe Michalski</a>'], 'photo_reference': 'AW30NDxFd584-oNBtqpEBrnU3KIm8ZBuxlVcPGQ7XRoJ-dUBce7JZk7lvIu0CVnKgQIu9SbCMYBMR4OP-uvzwXRhc7o8JPME_tOmB9tC2h-i0v_YbYnryhj04FomZof3DlIrBJ9EZ5WH0Jz0ppOWj2XtFH2QLjx-V_9T9DS2w3-KmfoDdKrL', 'width': 4032}], 'place_id': 'ChIJe9OrW-eq3oARuXXd8wQMg14', 'plus_code': {'compound_code': 'QR32+XW San Diego, California', 'global_code': '8544QR32+XW'}, 'price_level': 2, 'rating': 4.7, 'reference': 'ChIJe9OrW-eq3oARuXXd8wQMg14', 'types': ['tourist_attraction', 'park', 'point_of_interest', 'establishment'], 'user_ratings_total': 25115}, {'business_status': 'OPERATIONAL', 'formatted_address': '1492 N Harbor Dr, San Diego, CA 92101, United States', 'geometry': {'location': {'lat': 32.7209355, 'lng': -117.1739873}, 'viewport': {'northeast': {'lat': 32.72226312989272, 'lng': -117.1722953201073}, 'southwest': {'lat': 32.71956347010728, 'lng': -117.1749949798927}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png', 'icon_background_color': '#13B5C7', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet', 'name': 'Maritime Museum of San Diego', 'opening_hours': {'open_now': False}, 'photos': [{'height': 9000, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105086700026199637668">Raul Cantero</a>'], 'photo_reference': 'AW30NDzStU6AOax491wfgzUSwDenHTB3gjoUMr82TH_784X4P0yk_qj6gKdZipsLg4u0mOz9Dje5ydKFU7nh4j3l6H9utbP6guidCLH14CpU5ivKlqv3RYLgh4XUObfL5dCNinrqQ4qAPijdlYkRnIhFO6hJ0CDjhL3Bb7R4xGzb0909ldVE', 'width': 12000}], 'place_id': 'ChIJW3MFtlKr3oARYkZGRPnweDs', 'plus_code': {'compound_code': 'PRCG+9C San Diego, California', 'global_code': '8544PRCG+9C'}, 'rating': 4.7, 'reference': 'ChIJW3MFtlKr3oARYkZGRPnweDs', 'types': ['tourist_attraction', 'museum', 'point_of_interest', 'establishment'], 'user_ratings_total': 3485}, {'business_status': 'OPERATIONAL', 'formatted_address': '849 W Harbor Dr, San Diego, CA 92101, United States', 'geometry': {'location': {'lat': 32.7090645, 'lng': -117.1709366}, 'vi ...
#
#
# San Diego, CA, United States
# 4002 Wallace St, San Diego, CA 92110, United States
# 1492 N Harbor Dr, San Diego, CA 92101, United States
# 849 W Harbor Dr, San Diego, CA 92101, United States
# 1600 Pacific Hwy, San Diego, CA 92101, United States
# The, San Diego, CA 92101, United States
# 500 Sea World Dr., San Diego, CA 92109, United States
# 2920 Zoo Dr, San Diego, CA 92101, United States
# Eighth Ave, San Diego, CA 92101, United States
# 3165 Pacific Hwy, San Diego, CA 92101, United States
# 200 Fifth Ave, San Diego, CA 92101, United States
# 1350 El Prado, San Diego, CA 92101, United States
# W Mission Bay Dr, San Diego, CA 92109, United States
# 614 Fifth Ave, San Diego, CA 92101, United States
# 3146 Mission Blvd, San Diego, CA 92109, United States
# 3 Tuna Ln, San Diego, CA 92101, United States
# 1450 El Prado, San Diego, CA 92102, United States
# 200 Marina Park Way, San Diego, CA 92101, United States
# 1649 El Prado, San Diego, CA 92101, United States
# 3000 Mission Blvd, San Diego, CA 92109, United States
#                                                 name business_status  \
# 0                                        Balboa Park     OPERATIONAL
# 0             Old Town San Diego State Historic Park     OPERATIONAL
# 0                       Maritime Museum of San Diego     OPERATIONAL
# 0                                    Seaport Village     OPERATIONAL
# 0                                    Waterfront Park     OPERATIONAL
# 0                               San Diego Waterfront     OPERATIONAL
# 0                                 SeaWorld San Diego     OPERATIONAL
# 0                                      San Diego Zoo     OPERATIONAL
# 0                                      Marston Point     OPERATIONAL
# 0                                  Port of San Diego     OPERATIONAL
# 0                                San Diego Free Tour     OPERATIONAL
# 0                                       Museum of Us     OPERATIONAL
# 0         Mission Beach Boardwalk | Ocean Front Walk     OPERATIONAL
# 0  Gaslamp Quarter - The Historic Heart Of San Diego     OPERATIONAL
# 0                                       Belmont Park     OPERATIONAL
# 0                                   Tuna Harbor Park     OPERATIONAL
# 0                        The San Diego Museum of Art     OPERATIONAL
# 0                      Embarcadero Marina Park South     OPERATIONAL
# 0                    San Diego Model Railroad Museum     OPERATIONAL
# 0                                 Mission Beach Park     OPERATIONAL
#
#                                    formatted_address  rating  \
# 0                       San Diego, CA, United States     4.8
# 0  4002 Wallace St, San Diego, CA 92110, United S...     4.7
# 0  1492 N Harbor Dr, San Diego, CA 92101, United ...     4.7
# 0  849 W Harbor Dr, San Diego, CA 92101, United S...     4.6
# 0  1600 Pacific Hwy, San Diego, CA 92101, United ...     4.7
# 0            The, San Diego, CA 92101, United States     4.9
# 0  500 Sea World Dr., San Diego, CA 92109, United...     4.4
# 0    2920 Zoo Dr, San Diego, CA 92101, United States     4.7
# 0     Eighth Ave, San Diego, CA 92101, United States     4.5
# 0  3165 Pacific Hwy, San Diego, CA 92101, United ...     4.1
# 0  200 Fifth Ave, San Diego, CA 92101, United States     4.9
# 0  1350 El Prado, San Diego, CA 92101, United States     4.3
# 0  W Mission Bay Dr, San Diego, CA 92109, United ...     4.7
# 0  614 Fifth Ave, San Diego, CA 92101, United States     4.6
# 0  3146 Mission Blvd, San Diego, CA 92109, United...     4.5
# 0      3 Tuna Ln, San Diego, CA 92101, United States     4.7
# 0  1450 El Prado, San Diego, CA 92102, United States     4.6
# 0  200 Marina Park Way, San Diego, CA 92101, Unit...     4.7
# 0  1649 El Prado, San Diego, CA 92101, United States     4.6
# 0  3000 Mission Blvd, San Diego, CA 92109, United...     4.7
#
#    user_ratings_total                                            website  \
# 0               65606                         http://www.balboapark.org/
# 0               25115               http://www.parks.ca.gov/?page_id=663
# 0                3485                         http://www.sdmaritime.org/
# 0               24018                     http://www.seaportvillage.com/
# 0                8328  http://www.sandiegocounty.gov/content/sdc/park...
# 0                  10
# 0               41241  https://seaworld.com/san-diego?utm_source=goog...
# 0               47879                       https://zoo.sandiegozoo.org/
# 0                 111  https://www.sandiego.gov/park-and-recreation/p...
# 0                  54                    https://www.portofsandiego.org/
# 0                  15                            https://freesftour.com/
# 0                2008                         http://www.museumofus.org/
# 0                4200                          https://www.sandiego.gov/
# 0                 704                            http://www.gaslamp.org/
# 0               14679                        http://www.belmontpark.com/
# 0                1718  https://www.portofsandiego.org/where-to-go/emb...
# 0                1850                             http://www.sdmart.org/
# 0                2210  https://www.portofsandiego.org/where-go/embarc...
# 0                 802                              http://www.sdmrm.org/
# 0                6077  http://www.sandiego.org/what-to-do/beaches/mis...
#
#           lat           lng                     type
# 0  32.7341479   -117.144553                   museum
# 0  32.7549063  -117.1976407                     park
# 0  32.7209355  -117.1739873                   museum
# 0  32.7090645  -117.1709366            shopping_mall
# 0  32.7223013  -117.1722782                     park
# 0  32.7158242  -117.1733348                     tour
# 0  32.7641326  -117.2262952           amusement_park
# 0  32.7360353  -117.1509849                      zoo
# 0  32.7267578  -117.1579085                     park
# 0   32.735374  -117.1773834  local_government_office
# 0  32.7075856  -117.1602869                     tour
# 0  32.7315424  -117.1523679                   museum
# 0  32.7714323  -117.2528308                     park
# 0    32.71193   -117.160326                     tour
# 0   32.770895  -117.2518979           amusement_park
# 0  32.7127504  -117.1746646                     park
# 0   32.732158    -117.15043                   museum
# 0  32.7038654  -117.1643418                     park
# 0    32.73111  -117.1486199                   museum
# 0  32.7680765  -117.2519959                     park
#                                                       business_status  \
# name
# Balboa Park                                               OPERATIONAL
# Old Town San Diego State Historic Park                    OPERATIONAL
# Maritime Museum of San Diego                              OPERATIONAL
# Seaport Village                                           OPERATIONAL
# Waterfront Park                                           OPERATIONAL
# San Diego Waterfront                                      OPERATIONAL
# SeaWorld San Diego                                        OPERATIONAL
# San Diego Zoo                                             OPERATIONAL
# Marston Point                                             OPERATIONAL
# Port of San Diego                                         OPERATIONAL
# San Diego Free Tour                                       OPERATIONAL
# Museum of Us                                              OPERATIONAL
# Mission Beach Boardwalk | Ocean Front Walk                OPERATIONAL
# Gaslamp Quarter - The Historic Heart Of San Diego         OPERATIONAL
# Belmont Park                                              OPERATIONAL
# Tuna Harbor Park                                          OPERATIONAL
# The San Diego Museum of Art                               OPERATIONAL
# Embarcadero Marina Park South                             OPERATIONAL
# San Diego Model Railroad Museum                           OPERATIONAL
# Mission Beach Park                                        OPERATIONAL
# Village Hillcrest                                         OPERATIONAL
# Hillcrest Center                                          OPERATIONAL
# The Hub Hillcrest Market                                  OPERATIONAL
# Proactiv Kiosk                                            OPERATIONAL
# Old Town Enchanted Woods                           CLOSED_TEMPORARILY
# Perrt.t420 Glass Shop                                     OPERATIONAL
# Positive Phee                                             OPERATIONAL
# Robinson Plaza                                            OPERATIONAL
# Plaza On Fourth                                           OPERATIONAL
# The 50's on Fourth                                        OPERATIONAL
# Chopra Book Depot                                         OPERATIONAL
# Nenicheâ€™s Bazaar                                 CLOSED_TEMPORARILY
# Laz Parking Piazza della Famiglia Garage                  OPERATIONAL
# Mission Hills Plaza                                       OPERATIONAL
# Autozone                                           CLOSED_TEMPORARILY
#
#                                                                                    formatted_address  \
# name
# Balboa Park                                                             San Diego, CA, United States
# Old Town San Diego State Historic Park             4002 Wallace St, San Diego, CA 92110, United S...
# Maritime Museum of San Diego                       1492 N Harbor Dr, San Diego, CA 92101, United ...
# Seaport Village                                    849 W Harbor Dr, San Diego, CA 92101, United S...
# Waterfront Park                                    1600 Pacific Hwy, San Diego, CA 92101, United ...
# San Diego Waterfront                                         The, San Diego, CA 92101, United States
# SeaWorld San Diego                                 500 Sea World Dr., San Diego, CA 92109, United...
# San Diego Zoo                                        2920 Zoo Dr, San Diego, CA 92101, United States
# Marston Point                                         Eighth Ave, San Diego, CA 92101, United States
# Port of San Diego                                  3165 Pacific Hwy, San Diego, CA 92101, United ...
# Chopra Book Depot
# Nenicheâ€™s Bazaar
# Laz Parking Piazza della Famiglia Garage             4.3                  6
# Mission Hills Plaza                                  4.4                262
# Autozone
#
#                                                                                              website  \
# name
# Balboa Park                                                               http://www.balboapark.org/
# Old Town San Diego State Historic Park                          http://www.parks.ca.gov/?page_id=663
# Maritime Museum of San Diego                                              http://www.sdmaritime.org/
# Seaport Village                                                       http://www.seaportvillage.com/
# Waterfront Park                                    http://www.sandiegocounty.gov/content/sdc/park...
# San Diego Waterfront
# SeaWorld San Diego                                 https://seaworld.com/san-diego?utm_source=goog...
# San Diego Zoo                                                           https://zoo.sandiegozoo.org/
# Marston Point                                      https://www.sandiego.gov/park-and-recreation/p...
# Port of San Diego                                                    https://www.portofsandiego.org/
# San Diego Free Tour                                                          https://freesftour.com/
# Museum of Us                                                              http://www.museumofus.org/
# Mission Beach Boardwalk | Ocean Front Walk                                 https://www.sandiego.gov/
# Gaslamp Quarter - The Historic Heart Of San Diego                            http://www.gaslamp.org/
# Belmont Park                                                             http://www.belmontpark.com/
# Tuna Harbor Park                                   https://www.portofsandiego.org/where-to-go/emb...
# The San Diego Museum of Art                                                   http://www.sdmart.org/
# Embarcadero Marina Park South                      https://www.portofsandiego.org/where-go/embarc...
# San Diego Model Railroad Museum                                                http://www.sdmrm.org/
# Mission Beach Park                                 http://www.sandiego.org/what-to-do/beaches/mis...
# Village Hillcrest                                                   http://www.villagehillcrest.com/
# Hillcrest Center
# The Hub Hillcrest Market                           https://www.regencycenters.com/property/detail...
# Proactiv Kiosk
# Old Town Enchanted Woods
# Perrt.t420 Glass Shop
# Positive Phee                                                          https://www.positivephee.com/
# Robinson Plaza
# Plaza On Fourth
# The 50's on Fourth                                 http://www.mckeecommercialrealestate.com/the-5...
# Chopra Book Depot
# Nenicheâ€™s Bazaar
# Laz Parking Piazza della Famiglia Garage                                  http://www.lazparking.com/
# Mission Hills Plaza                                https://www.missionhillsplaza.com/?utm_source=...
# Autozone
#
#                                                           lat           lng  \
# name
# Balboa Park                                        32.7341479   -117.144553
# Old Town San Diego State Historic Park             32.7549063  -117.1976407
# Maritime Museum of San Diego                       32.7209355  -117.1739873
# Seaport Village                                    32.7090645  -117.1709366
# Waterfront Park                                    32.7223013  -117.1722782
# San Diego Waterfront                               32.7158242  -117.1733348
# SeaWorld San Diego                                 32.7641326  -117.2262952
# San Diego Zoo                                      32.7360353  -117.1509849
# Marston Point                                      32.7267578  -117.1579085
# Port of San Diego                                   32.735374  -117.1773834
# San Diego Free Tour                                32.7075856  -117.1602869
# Museum of Us                                       32.7315424  -117.1523679
# Mission Beach Boardwalk | Ocean Front Walk         32.7714323  -117.2528308
# Gaslamp Quarter - The Historic Heart Of San Diego    32.71193   -117.160326
# Belmont Park                                        32.770895  -117.2518979
# Tuna Harbor Park                                   32.7127504  -117.1746646
# The San Diego Museum of Art                         32.732158    -117.15043
# Embarcadero Marina Park South                      32.7038654  -117.1643418
# San Diego Model Railroad Museum                      32.73111  -117.1486199
# Mission Beach Park                                 32.7680765  -117.2519959
# Village Hillcrest                                  32.7492378  -117.1602169
# Hillcrest Center                                   32.7487792  -117.1588453
# The Hub Hillcrest Market                            32.749322  -117.1543118
# Proactiv Kiosk                                     32.7154042  -117.1572061
# Old Town Enchanted Woods                           32.7279499  -117.1708535
# Perrt.t420 Glass Shop                              32.7305305  -117.1618734
# Positive Phee                                      32.7477081  -117.1516825
# Robinson Plaza                                     32.7472219  -117.1613748
# Plaza On Fourth                                    32.7491239  -117.1619621
# The 50's on Fourth                                 32.7492509  -117.1618536
# Chopra Book Depot                                  32.7293403  -117.1707873
# Nenicheâ€™s Bazaar                                 32.7423385  -117.1307593
# Laz Parking Piazza della Famiglia Garage           32.7234431  -117.1677217
# Mission Hills Plaza                                32.7497046  -117.1680401
# Autozone                                           32.7162325  -117.1598743
#
#                                                                       type
# name
# Balboa Park                                                         museum
# Old Town San Diego State Historic Park                                park
# Maritime Museum of San Diego                                        museum
# Seaport Village                                              shopping_mall
# Waterfront Park                                                       park
# San Diego Waterfront                                                  tour
# SeaWorld San Diego                                          amusement_park
# San Diego Zoo                                                          zoo
# Marston Point                                                         park
# Port of San Diego                                  local_government_office
# San Diego Free Tour                                                   tour
# Museum of Us                                                        museum
# Mission Beach Boardwalk | Ocean Front Walk                            park
# Gaslamp Quarter - The Historic Heart Of San Diego                     tour
# Belmont Park                                                amusement_park
# Tuna Harbor Park                                                      park
# The San Diego Museum of Art                                         museum
# Embarcadero Marina Park South                                         park
# San Diego Model Railroad Museum                                     museum
# Mission Beach Park                                                    park
# Village Hillcrest                                                 shopping
# Hillcrest Center                                                  shopping
# The Hub Hillcrest Market                                          shopping
# Proactiv Kiosk                                                    shopping
# Old Town Enchanted Woods                                          shopping
# Perrt.t420 Glass Shop                                             shopping
# Positive Phee                                                     shopping
# Robinson Plaza                                                    shopping
# Plaza On Fourth                                                   shopping
# The 50's on Fourth                                                shopping
# Chopra Book Depot                                                 shopping
# Nenicheâ€™s Bazaar                                                shopping
# Laz Parking Piazza della Famiglia Garage                          shopping
# Mission Hills Plaza                                               shopping
# Autozone                                                          shopping

# %% [markdown]
# In this step we are getting the nearest shopping malls to our locations and to do this we are making use of KNN and BallTree in order to get the nearest points based on the haversine distance between the latitude and longitudes of the places. Later on we would be using this for further analysis.
#
# referenced from https://stackoverflow.com/questions/61952561/how-do-i-find-the-neighbors-of-points-containing-coordinates-in-python and modified to fit our use case

# %%
dfm = df[df['type']=='shopping']
dfm = dfm[['lat','lng']]
dfm['lat'] = dfm['lat'].astype(float)
dfm['lng'] = dfm['lng'].astype(float)

dfm['new_name'] = dfm.index
dfm.index = range(0,len(dfm['lat']))
dfm

#making use of the BallTree and haversine distances to get the nearest shopping malls
tree = BallTree(np.deg2rad(dfm[['lat', 'lng']].values), metric='haversine')
df_nomiss = pd.DataFrame({'lat':lats_nomiss,'lng':longs_nomiss},index=[0])

query_lats = df_nomiss['lat']
query_lons = df_nomiss['lng']

#using the knn inorder to get the shopping malls in the nearest vicinity to the locations
distances, indices = tree.query(np.deg2rad(np.c_[query_lats, query_lons]), k = len(dfm['lat']))

r_km = 6371
distance_matrix1 = {} #this has the nearest shopping malls to the locations which we can use for further analysis later
for name, d, ind in zip(dfm['new_name'], distances, indices):  
  for i, index in enumerate(ind):    
    distance_matrix1[dfm['new_name'][i]] = d[i]*r_km

# %% [markdown]
# Next we are calculating the distance matrix or the distance/driving time from a point to all other points in consideration and only the operational places are added to avoid surprises as we dont want to include non operational places and find out that it is closed on visiting the place.

# %%
#this code is to get the distance matrix or the distance/driving time from a point to all other points in consideration and only the operational places are added to avoid surprises
distance_matrix = pd.DataFrame({},columns=list(df[df['business_status']=='OPERATIONAL'].index),index=list(df[df['business_status']=='OPERATIONAL'].index))

#creating empty distance matrix to be populated later
x = list(distance_matrix.columns)
print(x)
for i in x:
    distance_matrix[i]=''
distance_matrix
# Out:
# ['Balboa Park', 'Old Town San Diego State Historic Park', 'Maritime Museum of San Diego', 'Seaport Village', 'Coronado Bridge', 'Waterfront Park', 'San Diego Waterfront', 'SeaWorld San Diego', 'California Tower', 'San Diego Zoo', 'Torrey Pines State Reserve', 'Broadway Pier', 'Port of San Diego', 'Old Point Loma Lighthouse', 'San Diego Free Tour', 'Museum of Us', 'Mission Beach Boardwalk | Ocean Front Walk', 'Gaslamp Quarter - The Historic Heart Of San Diego', 'Belmont Park', 'Embarcadero Marina Park South', 'Village Hillcrest', 'Hillcrest Center', 'The Hub Hillcrest Market', 'Proactiv Kiosk', 'Perrt.t420 Glass Shop', 'Positive Phee', 'Robinson Plaza', 'Plaza On Fourth', "The 50's on Fourth", 'Chopra Book Depot', 'Laz Parking Piazza della Famiglia Garage', 'Mission Hills Plaza']
#                                                   Balboa Park  \
# Balboa Park
# Old Town San Diego State Historic Park
# Maritime Museum of San Diego
# Seaport Village
# Coronado Bridge
# Waterfront Park
# San Diego Waterfront
# SeaWorld San Diego
# California Tower
# San Diego Zoo
# Torrey Pines State Reserve
# Broadway Pier
# Port of San Diego
# Old Point Loma Lighthouse
# San Diego Free Tour
# Museum of Us
# Mission Beach Boardwalk | Ocean Front Walk
# Gaslamp Quarter - The Historic Heart Of San Diego
# Belmont Park
# Embarcadero Marina Park South
# Village Hillcrest
# Hillcrest Center
# The Hub Hillcrest Market
# Proactiv Kiosk
# Perrt.t420 Glass Shop
# Positive Phee
# Robinson Plaza
# Plaza On Fourth
# The 50's on Fourth
# Chopra Book Depot
# Laz Parking Piazza della Famiglia Garage
# Mission Hills Plaza
#
#                                                   Old Town San Diego State Historic Park  \
# Balboa Park
# Old Town San Diego State Historic Park
# Maritime Museum of San Diego
# Seaport Village
# Coronado Bridge
# Waterfront Park
# San Diego Waterfront
# SeaWorld San Diego
# California Tower
# San Diego Zoo
# Torrey Pines State Reserve
# Broadway Pier
# Port of San Diego
# Old Point Loma Lighthouse
# San Diego Free Tour
# Museum of Us
# Mission Beach Boardwalk | Ocean Front Walk
# Gaslamp Quarter - The Historic Heart Of San Diego
# Belmont Park
# Embarcadero Marina Park South
# Village Hillcrest
# Hillcrest Center
# The Hub Hillcrest Market
# Proactiv Kiosk
# The distance from a place to itself is taken as 1 minute here as we are considering 1 minute as a buffer time to reach different places in the location and is the value returned from the distance matrix api. If needed we can also change this to 0 minutes.

# %%
count=0
for i in list(distance_matrix.index):
    for j in list(distance_matrix.columns):
        if distance_matrix[i][j]!='':
            distance_matrix.at[i,j] = distance_matrix[i][j]
            continue       
        
        lat = list(df[df.index.str.startswith(i)]['lat'])
        lng = list(df[df.index.str.startswith(i)]['lng'])
        lat1 = list(df[df.index.str.startswith(j)]['lat'])
        lng1 = list(df[df.index.str.startswith(j)]['lng'])

        print(str(lat[0])+' '+str(lng[0]))
        print(str(lat[0])+' '+str(lng[0]))

        try:
            #the call to distance matrix api and parsing the data we get from there in order to construct the distance matrix
            url = "https://maps.googleapis.com/maps/api/distancematrix/json?origins="+str(lat[0])+","+str(lng[0])+"&destinations="+str(lat1[0])+","+str(lng1[0])+"&key="+str(api_key)

            text = request.urlopen(url).read()
            s = BeautifulSoup(text,'html.parser')
            
            distance=json.loads(s.text)              
            
            distance_matrix.at[i,j] = str(distance['rows'][0]['elements'][0]['duration']['text'])
        except Exception as e:
            print("error")
distance_matrix
# Out:
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7341479 -117.144553
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7549063 -117.1976407
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.7209355 -117.1739873
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.6719911 -117.2410107
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7075856 -117.1602869
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7315424 -117.1523679
# 32.7714323 -117.2528308
# 32.7714323 -117.2528308
# 32.7714323 -117.2528308
# 32.7714323 -117.2528308
# 32.7714323 -117.2528308
# 32.7714323 -117.2528308
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7477006 -117.1516821
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7472185 -117.161355
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7491239 -117.1619621
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7492509 -117.1618536
# 32.7293403 -117.1707873
# 32.7293403 -117.1707873
# 32.7293403 -117.1707873
# 32.7293403 -117.1707873
# 32.7293403 -117.1707873
# 32.7293403 -117.1707873
# 32.7234431 -117.1677217
# 32.7234431 -117.1677217
# 32.7234431 -117.1677217
# 32.7234431 -117.1677217
# 32.7497046 -117.1680401
# 32.7497046 -117.1680401
#                                                   Balboa Park  \
# Balboa Park                                             1 min
# Old Town San Diego State Historic Park                10 mins
# Maritime Museum of San Diego                           8 mins
# Seaport Village                                       12 mins
# Coronado Bridge                                        8 mins
# Waterfront Park                                        8 mins
# San Diego Waterfront                                   9 mins
# SeaWorld San Diego                                    15 mins
# California Tower                                       7 mins
# San Diego Zoo                                          3 mins
# Torrey Pines State Reserve                            24 mins
# Broadway Pier                                         10 mins
# Port of San Diego                                      9 mins
# Old Point Loma Lighthouse                             26 mins
# San Diego Free Tour                                    8 mins
# Museum of Us                                           7 mins
# Mission Beach Boardwalk | Ocean Front Walk            15 mins
# Gaslamp Quarter - The Historic Heart Of San Diego     10 mins
# Belmont Park                                          14 mins
# Embarcadero Marina Park South                         11 mins
# Village Hillcrest                                      8 mins
# Hillcrest Center                                       7 mins
# The Hub Hillcrest Market                               6 mins
# Proactiv Kiosk                                         7 mins
# Perrt.t420 Glass Shop                                  6 mins
# Positive Phee                                          5 mins
# Robinson Plaza                                         9 mins
# Plaza On Fourth                                       10 mins
# The 50's on Fourth                                    10 mins
# Chopra Book Depot                                      7 mins
# Laz Parking Piazza della Famiglia Garage               7 mins
# Mission Hills Plaza                                    9 mins
#
#                                                   Old Town San Diego State Historic Park  \
# Balboa Park                                                                      10 mins
# Old Town San Diego State Historic Park                                             1 min
# Maritime Museum of San Diego                                                     12 mins
# Seaport Village                                                                  16 mins
# Coronado Bridge                                                                  14 mins
# Waterfront Park                                                                  12 mins
# San Diego Waterfront                                                             13 mins
# Plaza On Fourth                                                4 mins
# The 50's on Fourth                                             4 mins
# Chopra Book Depot                                              6 mins
# Laz Parking Piazza della Famiglia Garage                       9 mins
# Mission Hills Plaza                                             1 min
#
# [32 rows x 32 columns]

# %% [markdown]
# Next step is to select the most popular places we can visit. We are assuming that the place would be good if it has a good average rating from a large number of people which can tell 2 things.
#
# 1. The place is actually good if it has a good average rating
# 2. The place is visited by many people if it has a large number of ratings
# So inorder to remove bias in the ratings we are making sure that we consider the rating of the place only if has more than 2000 ratings( there might be some smaller places which are actually much more better and have a fewer reviews but we are ignoring these for now, like we are following the words of the majority in this case).
#
# We are also making sure that we select a place from each of the place types so that we dont end up taking people to similar places like to 2 museums etc on a single day so that we can maintain diversity in the tour schedule.

# %%
df.loc[df.rating == ' ', 'rating'] = '0.0'
df.loc[df.user_ratings_total == ' ', 'user_ratings_total'] = '0'
df_schedule = pd.DataFrame()

for i in list(set(list(df['type']))):
    if 'office' in i or 'store' in i:
        continue
    df1 = df[df['type']==i]
    df1 = df1[df1['user_ratings_total'].astype(int)>2000]  #filtering out places with less than 2000 reviews
    df1 = df1[df1['rating'].astype(float)>4.0]             #selecting a place with more than 4 star review
    
    df2 = df1.sort_values(['rating'],ascending=False)
    df3 = df2.sort_values(['user_ratings_total'],ascending=False)
    try:
      df4 = df3[df3.index.str.startswith(list(df3.index)[0])]   #selecting the best place with the maximum rating by sorting it on both the ratings and the number of ratings to reduce bias
    except Exception as e:
      continue
    print(df4)
    df_schedule = pd.concat([df_schedule, df4])
df_schedule
# Out:
#               business_status  \
# name
# San Diego Zoo     OPERATIONAL
#
#                                              formatted_address rating  \
# name
# San Diego Zoo  2920 Zoo Dr, San Diego, CA 92101, United States    4.7
#
#               user_ratings_total                       website         lat  \
# name
# San Diego Zoo              47819  https://zoo.sandiegozoo.org/  32.7360353
#
#                         lng type
# name
# San Diego Zoo  -117.1509849  zoo
#                          business_status  \
# name
# The Hub Hillcrest Market     OPERATIONAL
#
#                                                           formatted_address  \
# name
# The Hub Hillcrest Market  940-1092 University Ave, San Diego, CA 92103, USA
#
#                          rating user_ratings_total  \
# name
# The Hub Hillcrest Market    4.3               2229
#
#                                                                     website  \
# name
# The Hub Hillcrest Market  https://www.regencycenters.com/property/detail...
#
#                                 lat           lng      type
# name
# The Hub Hillcrest Market  32.749322  -117.1543118  shopping
#             business_status             formatted_address rating  \
# name
# Balboa Park     OPERATIONAL  San Diego, CA, United States    4.8
#
#             user_ratings_total                     website         lat  \
# name
# Balboa Park              65494  http://www.balboapark.org/  32.7341479
#
#                      lng    type
# name
# Balboa Park  -117.144553  museum
#                                        business_status  \
# name
# Old Town San Diego State Historic Park     OPERATIONAL
#
#                                                                         formatted_address  \
# name
# Old Town San Diego State Historic Park  4002 Wallace St, San Diego, CA 92110, United S...
#
#                                        rating user_ratings_total  \
# name
# Old Town San Diego State Historic Park    4.7              25079
#
#                                                                      website  \
# name
# Old Town San Diego State Historic Park  http://www.parks.ca.gov/?page_id=663
#
#                                                lat           lng  type
# name
# Old Town San Diego State Historic Park  32.7549063  -117.1976407  park
#                    business_status  \
# name
# SeaWorld San Diego     OPERATIONAL
#
#                                                     formatted_address rating  \
# name
# SeaWorld San Diego  500 Sea World Dr., San Diego, CA 92109, United...    4.4
#
#                    user_ratings_total  \
# name
# SeaWorld San Diego              41185
#
#                                                               website  \
# name
# SeaWorld San Diego  https://seaworld.com/san-diego?utm_source=goog...
#
#                            lat           lng            type
# name
# SeaWorld San Diego  32.7641326  -117.2262952  amusement_park
#                 business_status  \
# name
# Seaport Village     OPERATIONAL
#
#                                                  formatted_address rating  \
# name
# Seaport Village  849 W Harbor Dr, San Diego, CA 92101, United S...    4.6
#
#                 user_ratings_total                         website  \
# name
# Seaport Village              23972  http://www.seaportvillage.com/
#
#                         lat           lng           type
# name
# Seaport Village  32.7090645  -117.1709366  shopping_mall
#                                        business_status  \
# name
# San Diego Zoo                              OPERATIONAL
# The Hub Hillcrest Market                   OPERATIONAL
# Balboa Park                                OPERATIONAL
# Old Town San Diego State Historic Park     OPERATIONAL
# SeaWorld San Diego                         OPERATIONAL
# Seaport Village                            OPERATIONAL
#
#                                                                         formatted_address  \
# name
# San Diego Zoo                             2920 Zoo Dr, San Diego, CA 92101, United States
# The Hub Hillcrest Market                940-1092 University Ave, San Diego, CA 92103, USA
# Balboa Park                                                  San Diego, CA, United States
# Old Town San Diego State Historic Park  4002 Wallace St, San Diego, CA 92110, United S...
# SeaWorld San Diego                      500 Sea World Dr., San Diego, CA 92109, United...
# Seaport Village                         849 W Harbor Dr, San Diego, CA 92101, United S...
#
#                                        rating user_ratings_total  \
# name
# San Diego Zoo                             4.7              47819
# The Hub Hillcrest Market                  4.3               2229
# Balboa Park                               4.8              65494
# Old Town San Diego State Historic Park    4.7              25079
# SeaWorld San Diego                        4.4              41185
# Seaport Village                           4.6              23972
#
#                                                                                   website  \
# name
# San Diego Zoo                                                https://zoo.sandiegozoo.org/
# The Hub Hillcrest Market                https://www.regencycenters.com/property/detail...
# Balboa Park                                                    http://www.balboapark.org/
# Old Town San Diego State Historic Park               http://www.parks.ca.gov/?page_id=663
# SeaWorld San Diego                      https://seaworld.com/san-diego?utm_source=goog...
# Seaport Village                                            http://www.seaportvillage.com/
#
#                                                lat           lng  \
# name
# San Diego Zoo                           32.7360353  -117.1509849
# The Hub Hillcrest Market                 32.749322  -117.1543118
# Balboa Park                             32.7341479   -117.144553
# Old Town San Diego State Historic Park  32.7549063  -117.1976407
# SeaWorld San Diego                      32.7641326  -117.2262952
# Seaport Village                         32.7090645  -117.1709366
#
#                                                   type
# name
# San Diego Zoo                                      zoo
# The Hub Hillcrest Market                      shopping
# Balboa Park                                     museum
# Old Town San Diego State Historic Park            park
# SeaWorld San Diego                      amusement_park
# Seaport Village                          shopping_mall

# %%
#next we are just getting the subset of the distance matrix for the final list of places that we have selected from the step above so that we can plot the optimal path

distance_schedule = distance_matrix[df_schedule.index]
distance_schedule_final = distance_schedule[pd.DataFrame(distance_schedule.index.tolist()).isin(df_schedule.index).any(1).values]
distance_schedule_final = distance_schedule_final[list(distance_schedule_final.index)]
distance_schedule_final
# Out:
#                                        Balboa Park  \
# Balboa Park                                  1 min
# Old Town San Diego State Historic Park     10 mins
# Seaport Village                            12 mins
# SeaWorld San Diego                         15 mins
# San Diego Zoo                               3 mins
# The Hub Hillcrest Market                    6 mins
#
#                                        Old Town San Diego State Historic Park  \
# Balboa Park                                                           10 mins
# Old Town San Diego State Historic Park                                  1 min
# Seaport Village                                                       16 mins
# SeaWorld San Diego                                                    11 mins
# San Diego Zoo                                                         13 mins
# The Hub Hillcrest Market                                               9 mins
#
#                                        Seaport Village SeaWorld San Diego  \
# Balboa Park                                    12 mins            15 mins
# Old Town San Diego State Historic Park         16 mins            11 mins
# Seaport Village                                  1 min            19 mins
# SeaWorld San Diego                             19 mins              1 min
# San Diego Zoo                                  15 mins            16 mins
# The Hub Hillcrest Market                       15 mins            14 mins
#
#                                        San Diego Zoo The Hub Hillcrest Market
# Balboa Park                                   3 mins                   6 mins
# Old Town San Diego State Historic Park       13 mins                   9 mins
# Seaport Village                              15 mins                  15 mins
# SeaWorld San Diego                           16 mins                  14 mins
# San Diego Zoo                                  1 min                   8 mins
# The Hub Hillcrest Market                      8 mins                    1 min

# %%
#getting a numpy array so that we can pass it to the algorithms solving the travelling salesman problem
distance_array = distance_schedule_final.to_numpy()
distance_array
# Out:
# array([['1 min', '10 mins', '12 mins', '15 mins', '3 mins', '6 mins'],
#        ['10 mins', '1 min', '16 mins', '11 mins', '13 mins', '9 mins'],
#        ['12 mins', '16 mins', '1 min', '19 mins', '15 mins', '15 mins'],
#        ['15 mins', '11 mins', '19 mins', '1 min', '16 mins', '14 mins'],
#        ['3 mins', '13 mins', '15 mins', '16 mins', '1 min', '8 mins'],
#        ['6 mins', '9 mins', '15 mins', '14 mins', '8 mins', '1 min']],
#       dtype=object)

# %%
#converting the matrix values to intergers to get the optimal path
distance_array_final = []
for i in distance_array:
    temp = []
    for j in i:
        temp.append(int(j.split(' ')[0]))
    distance_array_final.append(temp)
distance_array_final
# Out:
# [[1, 10, 12, 15, 3, 6],
#  [10, 1, 16, 11, 13, 9],
#  [12, 16, 1, 19, 15, 15],
#  [15, 11, 19, 1, 16, 14],
#  [3, 13, 15, 16, 1, 8],
#  [6, 9, 15, 14, 8, 1]]

# %% [markdown]
# Next we are making use of Google OR tools inorder to implement the travelling salesman problem. We are using this inorder to get the optimal path from a starting location back to the same location and covering all the given locations and with a minimum cost( cost here is time so we make sure that we are covering all the places and coming back to start point in minimum cost).
#
# We are planning to return back to the start point or the Indianapolis Zoo as it is the nearest to the bus station and airport and hence making it easy for the students to reach home in Indianapolis or also in other states by catching a flight(if we think this tour is done during the last day of the session before all students leave home).
#
# More details on the travelling salesman problem is here https://en.wikipedia.org/wiki/Travelling_salesman_problem
#
# The code from below has been taken from the tutorial/documentation of OR tools and I found it better as it gives the most optimal solution for the travelling salesman problem in comparision to we writing the solution ourselves.

# %%
import ortools
from ortools.constraint_solver import pywrapcp
m = pywrapcp.RoutingIndexManager(len(distance_array_final),1, 0) #here 1 is that we all want to move in same direction and not like we have 2 cars and we want to split people in 2 of them and move seperately since students all would be going at once the parameter value here is 1.
# 0 parameter above means that we are starting from the point 0 in the numpy array or Indianapolis Zoo
routing = pywrapcp.RoutingModel(m)

# %%
def distance_callback(from_index, to_index):    
    from_node = m.IndexToNode(from_index)
    to_node = m.IndexToNode(to_index)
    return distance_array_final[from_node][to_node]

transit_callback_index = routing.RegisterTransitCallback(distance_callback)

# %%
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
search_parameters = pywrapcp.DefaultRoutingSearchParameters()
search_parameters.first_solution_strategy = (routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

# %%
#the code to get the most optimal path so that the time/cost is least
def print_solution(manager, routing, solution):    
    index = routing.Start(0)    
    plan_output = ''
    route_distance = 0
    while not routing.IsEnd(index):
        plan_output += ' {} ->'.format(manager.IndexToNode(index))
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += ' {}\n'.format(manager.IndexToNode(index))
    return plan_output

# %%
solution = routing.SolveWithParameters(search_parameters)
if solution:
    x = print_solution(m, routing, solution)

# %%
#list of all the places that we need to visit and the order in which we need to visit, we are also returning back to the zoo at the end
final_places = []
places = list(distance_schedule_final.index)
for i in (x.strip('\n').split('->')):
  final_places.append(places[int(i)])
final_places
# Out:
# ['Balboa Park',
#  'San Diego Zoo',
#  'The Hub Hillcrest Market',
#  'Old Town San Diego State Historic Park',
#  'SeaWorld San Diego',
#  'Seaport Village',
#  'Balboa Park']

# %%
df_schedule_ordered = df[['formatted_address','rating','user_ratings_total','website','type']].copy()
df_schedule_ordered = df_schedule_ordered.loc[final_places[:-1]]
df_schedule_ordered
# Out:
#                                                                         formatted_address  \
# name
# Balboa Park                                                  San Diego, CA, United States
# San Diego Zoo                             2920 Zoo Dr, San Diego, CA 92101, United States
# The Hub Hillcrest Market                940-1092 University Ave, San Diego, CA 92103, USA
# Old Town San Diego State Historic Park  4002 Wallace St, San Diego, CA 92110, United S...
# SeaWorld San Diego                      500 Sea World Dr., San Diego, CA 92109, United...
# Seaport Village                         849 W Harbor Dr, San Diego, CA 92101, United S...
#
#                                        rating user_ratings_total  \
# name
# Balboa Park                               4.8              65494
# San Diego Zoo                             4.7              47819
# The Hub Hillcrest Market                  4.3               2229
# Old Town San Diego State Historic Park    4.7              25079
# SeaWorld San Diego                        4.4              41185
# Seaport Village                           4.6              23972
#
#                                                                                   website  \
# name
# Balboa Park                                                    http://www.balboapark.org/
# San Diego Zoo                                                https://zoo.sandiegozoo.org/
# The Hub Hillcrest Market                https://www.regencycenters.com/property/detail...
# Old Town San Diego State Historic Park               http://www.parks.ca.gov/?page_id=663
# SeaWorld San Diego                      https://seaworld.com/san-diego?utm_source=goog...
# Seaport Village                                            http://www.seaportvillage.com/
#
#                                                   type
# name
# Balboa Park                                     museum
# San Diego Zoo                                      zoo
# The Hub Hillcrest Market                      shopping
# Old Town San Diego State Historic Park            park
# SeaWorld San Diego                      amusement_park
# Seaport Village                          shopping_mall

# %% [markdown]
# Next we develop the schedule based on the order of the places that we plan on visiting and we also add these extra attributes to get a precise understanding of the time.
#
# in_time* - approximate time we reach the place
# out_time* - approximate time at which we need to return to the car/bus
# time_at_venue - time that we spend in the place
# journey_time - time taken to reach the place from the previous place
# Here journey_time is time taken to reach the place from the previous place or the journey_time for X is the journey time to X from the previous place Y.
#
# We are also putting a buffer of 10 minutes at each location so that we can accomodate the time taken for onboarding and deboarding the passengers and waiting for any people who are late to board the bus. So if we enter the place at 2PM and time spent there is 2 hours then out_time or time to reach the bus is 4PM but we start at 4:10PM to next place to give some time so that we can wait for people to come and board the bus/car and be ready. So the in_time of the next place would be out_time+10minutes+journey_time_from_place_to_nextplace
#
# We are giving the following times at each place:
#
# Normal Places - 1hr 30min
# Lunch&Shopping - 2hr
#
# We can also change these as per the need.

# %%
#initializing the extra columns
df_schedule_ordered['activity'] = ''
df_schedule_ordered['in_time*'] = ''
df_schedule_ordered['out_time*'] = ''
df_schedule_ordered['time_at_venue*'] = ''
df_schedule_ordered['journey_time*'] = ''
count= 0 
for i in range(len(final_places)-1):
  if count==0:    
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'in_time*'] = '9 AM'
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'out_time*'] = '10:30 AM'
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'time_at_venue*'] = '1hr 30min'
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'journey_time*'] = '0 min'
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'activity'] = 'tour'
    count=count+1
  else:
    time_temp = list(df_schedule_ordered[df_schedule_ordered.index.str.startswith(final_places[i-1])]['out_time*'])[0]
    time_hours = int(time_temp.split(' ')[0].split(':')[0])      #getting the hours value
    time_minutes = int(time_temp.split(' ')[0].split(':')[1])    #getting the minutes value 
    temp_final = time_minutes+10+int(distance_matrix[final_places[i-1]][final_places[i]].split(' ')[0])  #getting the final time adding the 10min buffer and journey time 
    
    hours_final = (time_hours+int(temp_final//60))%12     #calculating the hour value of the in_time of the place
    if hours_final == 0:
      hours_final = 12                                    #replace 0 with 12 if the time is 12PM
    minutes_final = temp_final%60
    if minutes_final<10:
      minutes_final = '0'+str(minutes_final)             #padding the minutes with 0 if the minutes value is 2 we make it 02 with padding
    final_time = str(hours_final)+":"+str(minutes_final)+" PM"   #calculating final in_time and we are assuming it is always PM as we are starting at 9AM and spending 3.5 hours at zoo

    if list(df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i])]['type']=='shopping')[0]:
      buffer = 120
      time_words = '2hr'
      activity = 'lunch&shopping'
    else:
      buffer = 90
      time_words = '1hr 30min'
      activity = 'tour'
    
    #code to calculate the out_time for the place based on the type of the venue and we do the same calculations as we did for the in_time like padding minutes making 0 hour as 12 etc
    out_hours = (hours_final+int(buffer//60))%12
    if out_hours == 0:
      out_hours = 12
    extra = (int(minutes_final)+int(buffer%60))//60        #if the hour changes to next hour because of the minutes add the extra hour value to the out_time
    if extra>0:
      out_hours=out_hours+extra
    out_minutes = (int(minutes_final)+int(buffer%60))%60
    if out_minutes<10:
      out_minutes = '0'+str(out_minutes)
    out_time = str(out_hours)+":"+str(out_minutes)+" PM"

    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'in_time*'] = final_time
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'out_time*'] = out_time
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'time_at_venue*'] = time_words
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'journey_time*'] = distance_matrix[final_places[i-1]][final_places[i]]
    df_schedule_ordered.loc[df_schedule_ordered.index.str.startswith(final_places[i]),'activity'] = activity
df_schedule_ordered
# Out:
#                                                                         formatted_address  \
# name
# Balboa Park                                                  San Diego, CA, United States
# San Diego Zoo                             2920 Zoo Dr, San Diego, CA 92101, United States
# The Hub Hillcrest Market                940-1092 University Ave, San Diego, CA 92103, USA
# Old Town San Diego State Historic Park  4002 Wallace St, San Diego, CA 92110, United S...
# SeaWorld San Diego                      500 Sea World Dr., San Diego, CA 92109, United...
# Seaport Village                         849 W Harbor Dr, San Diego, CA 92101, United S...
#
#                                        rating user_ratings_total  \
# name
# Balboa Park                               4.8              65494
# San Diego Zoo                             4.7              47819
# The Hub Hillcrest Market                  4.3               2229
# Old Town San Diego State Historic Park    4.7              25079
# SeaWorld San Diego                        4.4              41185
# Seaport Village                           4.6              23972
#
#                                                                                   website  \
# name
# Balboa Park                                                    http://www.balboapark.org/
# San Diego Zoo                                                https://zoo.sandiegozoo.org/
# The Hub Hillcrest Market                https://www.regencycenters.com/property/detail...
# Old Town San Diego State Historic Park               http://www.parks.ca.gov/?page_id=663
# SeaWorld San Diego                      https://seaworld.com/san-diego?utm_source=goog...
# Seaport Village                                            http://www.seaportvillage.com/
#
#                                                   type        activity  \
# name
# Balboa Park                                     museum            tour
# San Diego Zoo                                      zoo            tour
# The Hub Hillcrest Market                      shopping  lunch&shopping
# Old Town San Diego State Historic Park            park            tour
# SeaWorld San Diego                      amusement_park            tour
# Seaport Village                          shopping_mall            tour
#
#                                         in_time* out_time* time_at_venue*  \
# name
# Balboa Park                                 9 AM  10:30 AM      1hr 30min
# San Diego Zoo                           10:43 PM  12:13 PM      1hr 30min
# The Hub Hillcrest Market                12:31 PM   2:31 PM            2hr
# Old Town San Diego State Historic Park   2:50 PM   4:20 PM      1hr 30min
# SeaWorld San Diego                       4:41 PM   6:11 PM      1hr 30min
# Seaport Village                          6:40 PM   8:10 PM      1hr 30min
#
#                                        journey_time*
# name
# Balboa Park                                    0 min
# San Diego Zoo                                 3 mins
# The Hub Hillcrest Market                      8 mins
# Old Town San Diego State Historic Park        9 mins
# SeaWorld San Diego                           11 mins
# Seaport Village                              19 mins

# %%
df_schedule_ordered.to_csv('final_schedule.csv')
